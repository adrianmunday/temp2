# %%
import json
from openai import OpenAI
import requests
from typing import Dict, Any, Optional

# Initialize the OpenAI client with the DeepSeek API base URL
client = OpenAI(
    api_key="xxx",  # Remove when sharing!
    base_url="https://api.deepseek.com",
)

# Prompt for generating the initial report (regulations and controls)
generate_report_prompt = """
You are an expert researcher specializing in operational risk for banks. The user will provide a specific risk type.
Please respond with the following:
1. A list of regulations or industry standards relevant to the specified risk type.
2. A list of 15-30 controls relevant to this risk, including short descriptions.
3. An overview of observations, trends or emerging themes

User will provide the risk type, and you will respond with a list of regulations, a list of controls with their brief
descriptions and any additional obversations around trends or emerging themes
"""

# Prompt for refining the report and adding observations
refine_report_prompt = """
You are a senioer manager specializing in operational risk for banks. The user will provide a report output that you previously generated.
Please:
1. Review the provided report and identify any areas for improvement.
2. Provide a comment section called "Critique", summarizing:
    - Any significant gaps or areas where more detail is needed.
    - Suggestions for additional regulations or controls that might be relevant.
"""


def generate_report(risk_type: str) -> Optional[Dict[str, Any]]:
    """Generates an initial report on the specified risk type."""
    user_prompt = f"Risk Type: {risk_type}"
    messages = [
        {
            "role": "system",
            "content": generate_report_prompt,
        },
        {"role": "user", "content": user_prompt},
    ]
    try:
        # DeepSeek API call
        response = client.chat.completions.create(
            model="deepseek-reasoner",
            messages=messages,
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error during report generation:", str(e))
        return None


def refine_report(report: str) -> Optional[str]:
    """Refines the initial report and adds observations."""
    user_prompt = f"""
    Please review and refine the following report:
    {report}
    """
    messages = [
        {"role": "system", "content": refine_report_prompt},
        {"role": "user", "content": user_prompt},
    ]
    try:
        response = client.chat.completions.create(
            model="deepseek-reasoner",
            messages=messages,
        )
        # Return the response directly as a string
        return response.choices[0].message.content
    except Exception as e:
        print("Error during report refinement:", str(e))
        return None


# Implementation:
if __name__ == "__main__":
    risk_type = "Third Party Risk"  # Specify the risk type
    print(f"Generating report for Risk Type: {risk_type}")

    # Step 1: Generate initial report
    initial_report = generate_report(risk_type)
    if initial_report:
        print("\nInitial Report:")
        print(initial_report)

        # Step 2: Refine report
        refined_report = refine_report(initial_report)
        if refined_report:
            print("\nRefined Report with Observations:")
            print(refined_report)
# Out:
# Generating report for Risk Type: Third Party Risk
#
# Initial Report:
# ### **1. Regulations & Industry Standards for Third-Party Risk**
# - **Basel III/BCBS 239 (2013)**: Principles for effective risk data aggregation and reporting, including third-party dependencies.
# - **OCC Bulletin 2013-29 (US)**: Guidelines for third-party relationship risk management for national banks.
# - **EBA Guidelines on Outsourcing (2019)**: EU standards for financial institutions outsourcing to third parties, including cloud providers.
# - **GDPR (EU, 2018)**: Data protection requirements for third parties processing EU citizen data.
# - **FFIEC Third-Party Guidance (2021)**: US interagency guidance on managing risks in third-party relationships.
# - **DORA (EU, 2025)**: Digital Operational Resilience Act requiring robust IT third-party risk management.
# - **ISO 27001/27701**: Standards for information security and privacy in vendor relationships.
# - **Dodd-Frank Act (US, 2010)**: Stress testing and oversight of critical third parties in systemic risk.
# - **UK SMCR (2016)**: Senior Managers accountable for third-party risk oversight.
# - **MAS TRM Guidelines (Singapore, 2021)**: Technology risk management for outsourced services.
#
# ---
#
# ### **2. Controls for Third-Party Risk**
# 1. **Vendor Due Diligence**: Pre-engagement assessment of financial health, cybersecurity, compliance, and reputation.
# 2. **Contractual Risk Allocation**: Enforce SLAs, audit rights, data ownership, and liability clauses.
# 3. **Third-Party Risk Assessments**: Periodic evaluations of criticality, geographic risk, and compliance gaps.
# 4. **Continuous Monitoring**: Real-time tracking of vendor performance, breaches, or financial instability.
# 5. **Exit Strategy Planning**: Contingency plans for transitioning services if a vendor fails.
# 6. **Incident Response Coordination**: Joint protocols for cyberattacks/data breaches involving vendors.
# 7. **Cybersecurity Assessments**: Penetration testing and SOC 2/ISO 27001 validation.
# 8. **Employee Training**: Staff education on vendor risk identification and escalation.
# 9. **Compliance Audits**: Independent reviews of vendor adherence to regulations (e.g., GDPR, SOX).
# 10. **Concentration Risk Management**: Diversification of vendors to avoid over-reliance.
# 11. **Data Protection Controls**: Encryption, access limits, and DPIAs for shared data.
# 12. **Subcontractor Oversight**: Ensure primary vendors monitor their own third parties.
# 13. **Insurance Verification**: Require vendors to hold cyber liability/E&O insurance.
# 14. **Business Continuity Reviews**: Validate vendor disaster recovery plans.
# 15. **Reputation Monitoring**: Track vendors for ESG controversies or legal issues.
# 16. **Financial Penalties**: Enforce contractual consequences for non-compliance.
# 17. **Third-Party Risk Committee**: Cross-functional governance for oversight.
# 18. **Automated Vendor Risk Tools**: AI-driven platforms for risk scoring and alerts.
# 19. **Whistleblower Channels**: Anonymous reporting for vendor misconduct.
# 20. **Red Team Exercises**: Simulate vendor-driven attack scenarios.
# 21. **Vendor Tiering**: Classify vendors by risk level (e.g., critical, high, medium).
# 22. **Ethical Compliance Checks**: Screen vendors for modern slavery/environmental violations.
# 23. **Geopolitical Risk Analysis**: Assess vendor locations for sanctions or instability.
# 24. **Performance Metrics**: Track KPIs like uptime, incident resolution time.
# 25. **Right-to-Audit Clauses**: Contractual access to vendor facilities/records.
#
# ---
#
# ### **3. Observations, Trends & Emerging Themes**
# - **Regulatory Harmonization**: Global alignment (e.g., DORA, FFIEC) on third-party resilience, especially for cloud/IT providers.
# - **Cybersecurity Escalation**: 60% of breaches originate from third parties (IBM 2023); regulators now mandate incident reporting timelines.
# - **AI-Driven Monitoring**: Adoption of AI tools for predictive vendor risk analytics and continuous control testing.
# - **Fourth-Party Risk**: Scrutiny of subcontractors (e.g., cloud providers relying on hyperscalers) extending risk chains.
# - **ESG Integration**: Vendors assessed for carbon footprint, labor practices, and governance alongside financial risks.
# - **Geopolitical Fragmentation**: Nearshoring due to US-China tensions and sanctions (e.g., Russia-related vendor exclusions).
# - **Operational Resilience**: Post-pandemic focus on dual-vendor strategies and stress testing for critical services.
# - **Board Accountability**: Rising personal liability for executives under regimes like SMCR and SEC rules.
# - **Real-Time Dashboards**: Shift from annual reviews to dynamic risk scoring via APIs and integrated platforms.
# - **Cyber Insurance Gaps**: Insurers demanding stricter third-party controls for coverage eligibility.
#
# Let me know if you need deeper analysis on any area!
#
# Refined Report with Observations:
# ### **Critique of Provided Report**
# The report is comprehensive but has areas where depth, clarity, and alignment with emerging risks could be enhanced. Below are key gaps and recommendations:
#
# ---
#
# #### **1. Regulations & Industry Standards: Gaps**
# - **Missing Regional Regulations**:
#   - No mention of APAC regulations beyond Singapore’s MAS TRM (e.g., Australia’s APRA CPS 234, India’s RBI Master Direction on IT Outsourcing).
#   - Omission of cloud-specific frameworks like the **EU Cloud Code of Conduct** or **NIST SP 800-145** (cloud computing definitions).
# - **Incomplete Coverage of Sector-Specific Rules**:
#   - **PSD2 (EU)** for payment service providers and **NYDFS Cybersecurity Regulation (23 NYCRR 500)** for financial services in New York.
#   - **CCPA (US)** for California-specific data privacy, which impacts vendors handling Californian data.
# - **Ambiguity in Implementation Timelines**:
#   - DORA’s enforcement begins in 2025, but preparation requirements (e.g., ICT third-party registers) need clarification.
#
# ---
#
# #### **2. Controls for Third-Party Risk: Areas for Enhancement**
# - **Subcontractor Governance**:
#   - Control #12 (“Subcontractor Oversight”) lacks specificity. Recommend adding **flow-down clauses** in contracts to bind subcontractors to the same standards as primary vendors.
# - **Ethical Compliance**:
#   - Control #22 should reference **modern slavery acts** (e.g., UK Modern Slavery Act 2015, Australia’s Modern Slavery Act 2018) and **conflict minerals disclosures**.
# - **Supply Chain Security**:
#   - Missing controls for **software bill of materials (SBOM)** validation (aligned with **NTIA guidelines** or **CISA’s SCuBA**).
# - **Regulatory Mapping**:
#   - Controls (e.g., GDPR data protection) should explicitly link to regulations (e.g., Article 28 requirements for processors).
#
# ---
#
# #### **3. Observations & Trends: Missing Context**
# - **AI-Specific Risks**:
#   - While AI-driven monitoring is noted, risks like **algorithmic bias in vendor scoring** or **AI supply chain vulnerabilities** (e.g., reliance on third-party ML models) are omitted.
# - **Climate Resilience**:
#   - ESG integration (#5) should include **physical climate risk assessments** for vendors in flood/fire-prone regions.
# - **Sovereign Cloud Requirements**:
#   - Geopolitical trends (#6) lack examples like the EU’s **GAIA-X** initiative or data localization laws (e.g., China’s DSL, Russia’s Data Localization Law).
# - **Quantum Readiness**:
#   - No mention of **post-quantum cryptography requirements** for vendors handling sensitive long-term data.
#
# ---
#
# #### **4. Structural Improvements**
# - **Prioritization Framework**:
#   - Tier vendors not just by “criticality” but by **impact on financial stability** (e.g., alignment with **FSB’s guidance on critical third parties**).
# - **Implementation Challenges**:
#   - Add a section on common pitfalls (e.g., over-reliance on contractual clauses without operational testing, lack of board-level KPI reporting).
# - **Case Studies**:
#   - Reference real-world failures (e.g., 2020 SolarWinds breach, 2023 MOVEit attacks) to illustrate control gaps.
#
# ---
#
# ### **Suggestions for Additional Regulations & Controls**
# 1. **Regulations**:
#    - **FCA/PRA Operational Resilience Rules (UK, 2022)**: Mapping third-party dependencies to impact tolerances.
#    - **EU Data Act (2024)**: Requirements for cloud interoperability and data sharing.
#    - **SEC Cybersecurity Disclosure Rules (2023)**: Public reporting of material third-party breaches.
#    - **CJIS Security Policy (US)**: For vendors handling criminal justice data.
#
# 2. **Controls**:
#    - **Third-Party Incident Simulation**: Tabletop exercises with vendors for ransomware/data exfiltration scenarios.
#    - **SBOM Validation**: Automated checks for open-source vulnerabilities (e.g., Log4j).
#    - **Resilience Testing**: Align vendor BC/DR plans with **ISO 22301** standards.
#    - **Vendor Code Review Rights**: For critical software providers (mirroring **CISA’s Secure by Design** principles).
#
# ---
#
# ### **Final Recommendations**
# - **Integrate a “Regulatory Mapping Matrix”**: Link each control to specific regulations (e.g., SOC 2 ⇨ FFIEC, DPIAs ⇨ GDPR).
# - **Expand Geopolitical Analysis**: Include tools like **OFAC sanctions screening** for vendor transactions.
# - **Address Emerging Tech**: Add guidance on **generative AI vendor risks** (e.g., data poisoning, IP leakage).
#
# Let me know if you’d like a revised version incorporating these points!

# %%
import json
from openai import OpenAI
import requests
from typing import Dict, Any, Optional

# Initialize the OpenAI client with the DeepSeek API base URL
client = OpenAI(
    api_key="xxx",  # Remove when sharing!
    base_url="https://api.deepseek.com",
)

# Prompt for generating the initial report (regulations and controls)
generate_report_prompt = """
You are an expert researcher specializing in operational risk for banks. The user will provide a specific risk type.
Please respond with the following:
1. A list of regulations or industry standards relevant to the specified risk type.
2. A list of 15-30 controls relevant to this risk, including short descriptions.
3. An overview of observations, trends or emerging themes

User will provide the risk type, and you will respond with a list of regulations, a list of controls with their brief
descriptions and any additional obversations around trends or emerging themes
"""

# Prompt for refining the report and adding observations
refine_report_prompt = """
You are a senioer manager specializing in operational risk for banks. The user will provide a report output that you previously generated.
Please:
1. Review the provided report and identify any areas for improvement.
2. Provide a comment section called "Critique", summarizing:
    - Any significant gaps or areas where more detail is needed.
    - Suggestions for additional regulations or controls that might be relevant.
"""


def generate_report(risk_type: str) -> Optional[Dict[str, Any]]:
    """Generates an initial report on the specified risk type."""
    user_prompt = f"Risk Type: {risk_type}"
    messages = [
        {
            "role": "system",
            "content": generate_report_prompt,
        },
        {"role": "user", "content": user_prompt},
    ]
    try:
        # DeepSeek API call
        response = client.chat.completions.create(
            model="deepseek-reasoner",
            messages=messages,
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error during report generation:", str(e))
        return None


def refine_report(report: str) -> Optional[str]:
    """Refines the initial report and adds observations."""
    user_prompt = f"""
    Please review and refine the following report:
    {report}
    """
    messages = [
        {"role": "system", "content": refine_report_prompt},
        {"role": "user", "content": user_prompt},
    ]
    try:
        response = client.chat.completions.create(
            model="deepseek-reasoner",
            messages=messages,
        )
        # Return the response directly as a string
        return response.choices[0].message.content
    except Exception as e:
        print("Error during report refinement:", str(e))
        return None


# Implementation:
if __name__ == "__main__":
    risk_type = "Cyber Security Risk"  # Specify the risk type
    print(f"Generating report for Risk Type: {risk_type}")

    # Step 1: Generate initial report
    initial_report = generate_report(risk_type)
    if initial_report:
        print("\nInitial Report:")
        print(initial_report)

        # Step 2: Refine report
        refined_report = refine_report(initial_report)
        if refined_report:
            print("\nRefined Report with Observations:")
            print(refined_report)
# Out:
# Generating report for Risk Type: Cyber Security Risk
#
# Initial Report:
# ### **1. Relevant Regulations & Industry Standards**
# - **General Data Protection Regulation (GDPR)** (EU): Protects personal data and mandates breach notifications.
# - **GLBA Safeguards Rule** (US): Requires financial institutions to secure customer data.
# - **NYDFS Cybersecurity Regulation (23 NYCRR 500)** (US): Mandates cybersecurity programs for NY-regulated banks.
# - **FFIEC IT Examination Handbook** (US): Framework for managing IT and cybersecurity risks.
# - **PCI DSS**: Standards for securing payment card data.
# - **ISO/IEC 27001**: International standard for information security management.
# - **NIST Cybersecurity Framework** (US): Risk-based approach to managing cyber risks.
# - **DORA** (EU): Ensures operational resilience of financial entities against ICT risks.
# - **EBA Guidelines on ICT and Security Risk Management** (EU): Specific to EU banking authorities.
# - **MAS Technology Risk Management Guidelines** (Singapore): Requirements for financial institutions.
# - **CPMI-IOSCO Guidance on Cyber Resilience**: For financial market infrastructures.
# - **SOX**: Requires internal controls over financial reporting, including IT systems.
# - **NIS2 Directive** (EU): Expands cybersecurity requirements for critical sectors, including finance.
#
# ---
#
# ### **2. Cyber Security Controls**
# 1. **Network Segmentation**: Isolate critical systems to limit lateral movement during breaches.
# 2. **Multi-Factor Authentication (MFA)**: Enforce MFA for all privileged accounts and remote access.
# 3. **Data Encryption**: Encrypt data at rest and in transit (e.g., TLS, AES-256).
# 4. **Vulnerability Management**: Regular scans and prioritization of patch deployment.
# 5. **Endpoint Detection & Response (EDR)**: Monitor endpoints for malicious activity.
# 6. **Security Information and Event Management (SIEM)**: Centralized log analysis for threat detection.
# 7. **Incident Response Plan**: Documented playbooks with roles, escalation paths, and communication protocols.
# 8. **Phishing Simulations**: Train employees to recognize malicious emails.
# 9. **Role-Based Access Control (RBAC)**: Restrict system access to least privilege.
# 10. **Third-Party Risk Assessments**: Evaluate vendors’ cybersecurity practices.
# 11. **Backup & Disaster Recovery**: Air-gapped backups tested for ransomware resilience.
# 12. **Penetration Testing**: Annual red-team exercises to identify gaps.
# 13. **Threat Intelligence Integration**: Feed external threat data into monitoring tools.
# 14. **Data Loss Prevention (DLP)**: Monitor and block unauthorized data transfers.
# 15. **Zero Trust Architecture**: Verify every access request, even from internal networks.
# 16. **Secure Software Development Lifecycle (SDLC)**: Code reviews, static analysis, and vulnerability testing.
# 17. **Privileged Access Management (PAM)**: Vault and rotate credentials for admin accounts.
# 18. **Deception Technologies**: Deploy honeypots to detect attackers.
# 19. **Ransomware-Specific Controls**: Allowlisting, macro blocking, and immutable backups.
# 20. **Cloud Security Posture Management (CSPM)**: Automate misconfiguration detection in cloud environments.
# 21. **Identity Governance**: Regular access reviews and orphaned account cleanup.
# 22. **Dark Web Monitoring**: Scan for leaked credentials or company data.
# 23. **AI/ML Anomaly Detection**: Identify unusual behavior in user activity or network traffic.
# 24. **IoT Device Hardening**: Secure non-traditional endpoints (e.g., ATMs, smart buildings).
# 25. **Cyber Insurance**: Transfer risk with policies covering ransomware, business interruption, etc.
# 26. **Board Reporting**: Regular updates to executives on cyber risk posture and incidents.
#
# ---
#
# ### **3. Observations, Trends & Emerging Themes**
# - **Ransomware Evolution**: Attacks increasingly target supply chains and exploit SaaS platforms.
# - **Cloud Risks**: Rapid cloud adoption outpaces security maturity, leading to misconfigurations.
# - **AI Arms Race**: Attackers use generative AI for phishing, while defenders deploy AI for anomaly detection.
# - **Regulatory Fragmentation**: Overlapping requirements (e.g., NIS2, DORA, state laws) complicate compliance.
# - **Supply Chain Attacks**: Focus on compromising software vendors (e.g., SolarWinds, Log4j).
# - **Operational Resilience Shift**: Regulators emphasize continuity planning beyond traditional cybersecurity.
# - **Skills Gap**: Shortage of cyber talent drives demand for managed detection and response (MDR) services.
# - **Quantum Preparedness**: Banks piloting post-quantum cryptography to future-proof encryption.
# - **API Security**: Open banking and fintech partnerships increase exposure to insecure APIs.
# - **Geopolitical Cyber Threats**: State-sponsored actors targeting financial infrastructure for disruption.
#
# Let me know if you need further details on any specific area!
#
# Refined Report with Observations:
# ### **Critique**
# The report provides a solid foundation but has opportunities for enhancement in alignment with global operational risk management best practices. Below are key gaps and recommendations:
#
# ---
#
# #### **Significant Gaps & Areas Needing Detail**
# 1. **Regulatory Coverage**:
#    - Missing **Basel Committee on Banking Supervision (BCBS) standards**, particularly **BCBS 239** (risk data aggregation) and **BCBS 425** (operational resilience).
#    - Omission of **SEC Cybersecurity Disclosure Rules** (2023), requiring public companies to report material incidents within 4 days.
#    - Limited APAC coverage beyond Singapore (e.g., Australia’s **APRA CPS 234**, Hong Kong’s **HKMA TM-E-1**).
#    - No mention of **PSD2** (EU) for open banking security or the **Critical Entities Resilience (CER) Directive** (EU), which complements NIS2.
#
# 2. **Control Enhancements**:
#    - **Insider Threat Programs**: Explicit controls for monitoring malicious internal activity (e.g., user behavior analytics).
#    - **Application Security**: Runtime protections (e.g., Web Application Firewalls/WAFs) and mobile app hardening.
#    - **Supply Chain Security**: Software Bill of Materials (SBOM) adoption and vendor certification requirements (e.g., SOC 2).
#    - **Crisis Communication**: Integration with external stakeholders (e.g., regulators, law enforcement) in incident plans.
#    - **Physical-Digital Convergence**: Securing IoT in physical infrastructure (e.g., biometric access controls for data centers).
#
# 3. **Observations & Trends**:
#    - No reference to **executive accountability** (e.g., EU’s DORA penalties for management failures).
#    - Missing **DeFi/Crypto Risks** (e.g., wallet security, smart contract vulnerabilities) for banks in digital asset markets.
#    - Underemphasis on **deepfake fraud** and **voice phishing (vishing)** as emerging social engineering threats.
#
# ---
#
# #### **Suggested Additions**
# **Regulations**:
# - **BCBS 239**: Strengthen risk data governance.
# - **SEC Regulation S-K Item 106**: Mandate incident disclosure timelines.
# - **APRA CPS 234** (Australia) and **FSS Act** (South Korea): Expand APAC coverage.
# - **Digital Identity Guidelines** (e.g., NIST SP 800-63-3): For robust authentication frameworks.
#
# **Controls**:
# - **CASB (Cloud Access Security Broker)**: Enforce granular cloud access policies.
# - **Fraud Detection Systems**: AI-driven tools to combat payment fraud and account takeovers.
# - **Control Testing Automation**: Tools like Breach and Attack Simulation (BAS) for continuous validation.
# - **SBOM Integration**: Track third-party software vulnerabilities proactively.
#
# **Emerging Themes**:
# - **Regulatory Scrutiny of Executives**: Link cyber failures to director liability (e.g., UK Senior Managers Regime).
# - **Quantum Computing Risks**: Expand beyond “preparedness” to include migration timelines for crypto-agility.
# - **Synthetic Media Threats**: Address AI-generated content in fraud scenarios.
#
# ---
#
# ### **Refinement Recommendations**
# - **Map Regulations to Controls**: For example, link DORA’s operational resilience requirements to incident response and backup controls.
# - **Prioritize Controls by Risk Tier**: Highlight “critical” controls (e.g., MFA, encryption) versus “enhanced” (e.g., deception technologies).
# - **Include Metrics**: Add KPIs for control effectiveness (e.g., mean time to patch, incident response time).
#
# Let me know if you’d like to explore specific additions in-depth!
